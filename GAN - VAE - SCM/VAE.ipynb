# %% [markdown]
# # TP Coding autoencoders and variational autoencoders in Pytorch
#
#
# Author : Alasdair Newson
#
# alasdair.newson@telecom-paris.fr
#
# ## Objective:
#
# The goal of this TP is to explore autoencoders and variational autoencoders applied to a simple dataset. In this first part, we will look at an autoencoder applied to MNIST. We recall that an autoencoder is a neural network with the following general architecture:
#
#
# ![AUTOENCODER](https://perso.telecom-paristech.fr/anewson/doc/images/autoencoder_illustration_2.png)
#
# The tensor $z$ in the middle of the network is called a __latent code__, and it belongs to the latent space. It is this latent space which is interesting in autoencoders (for image synthesis, editing, etc).
#
# ### Your task:
# You need to add the missing parts in the code (parts between # --- START CODE HERE and # --- END CODE HERE or # FILL IN CODE)
#
#
# First of all, let's load some packages

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable
from torchvision.utils import save_image

import pdb
import numpy as np
import matplotlib.pyplot as plt

def pytorch_to_numpy(x):
  return x.detach().numpy()

# %% [markdown]
# First, we load the mnist dataset.

# %%
batch_size = 128

# MNIST Dataset
mnist_trainset = datasets.MNIST(root='./mnist_data/', train=True, transform=transforms.ToTensor(), download=True)
mnist_testset = datasets.MNIST(root='./mnist_data/', train=False, transform=transforms.ToTensor(), download=False)

#create data loader with smaller dataset size
max_mnist_size = 1000
mnist_trainset_reduced = torch.utils.data.random_split(mnist_trainset, [max_mnist_size, len(mnist_trainset)-max_mnist_size])[0]
mnist_train_loader = torch.utils.data.DataLoader(mnist_trainset_reduced, batch_size=batch_size, shuffle=True,drop_last=True)

# download test dataset
max_mnist_size = 512
mnist_testset_reduced = torch.utils.data.random_split(mnist_testset, [max_mnist_size, len(mnist_testset)-max_mnist_size])[0]
mnist_test_loader = torch.utils.data.DataLoader(mnist_testset_reduced, batch_size=batch_size, shuffle=True,drop_last=True)
# Out:
# 100%|██████████| 9.91M/9.91M [00:01<00:00, 5.12MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 134kB/s]
# 100%|██████████| 1.65M/1.65M [00:01<00:00, 1.26MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 13.1MB/s]

# %%
mnist_trainset_reduced.dataset.train_data.shape
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/datasets/mnist.py:76: UserWarning: train_data has been renamed data
#   warnings.warn("train_data has been renamed data")
# torch.Size([60000, 28, 28])

# %% [markdown]
# # 1 Vanilla Autoencoder
#
# Now, we define the general parameters of the autoencoder

# %%
# autoencoder parameters
n_rows = mnist_trainset_reduced.dataset.train_data.shape[1]
n_cols = mnist_trainset_reduced.dataset.train_data.shape[2]
n_channels = 1
n_pixels = n_rows*n_cols

img_shape = (n_rows, n_cols, n_channels)
n_epochs = 150

# %% [markdown]
# Now, define the autoencoder architecture. In the first part, we will use the following MLP architecture :
#
# Encoder :
# - Flatten input
# - Dense layer, output size h_dim_1 + ReLU
# - Dense layer, output size h_dim_2 + ReLU
# - Dense layer, output size z_dim (no non-linearity)
#
# Decoder :
# - Dense layer, output size h_dim_2 + ReLU
# - Dense layer, output size h_dim_1 + ReLU
# - Dense layer, output size x_dim + Sigmoid Activation
# - Reshape, to size $28\times 28\times 1$
#
# For the Reshape operation, use the ```A.view(dim_1,dim_2,...)``` function, where ```A``` is your tensor.

# %%
class AE(torch.nn.Module ):
  def __init__(self, x_dim, h_dim1, h_dim2, z_dim,n_rows,n_cols,n_channels):
    super(AE, self).__init__()

    self.n_rows = n_rows
    self.n_cols = n_cols
    self.n_channels = n_channels
    self.n_pixels = (self.n_rows)*(self.n_cols)
    self.z_dim = z_dim

    # encoder part
    self.fc1 = nn.Linear(n_rows*n_cols, h_dim1) # FILL IN CODE HERE
    self.fc2 = nn.Linear(h_dim1, h_dim2) # FILL IN CODE HERE
    self.fc3 = nn.Linear(h_dim2, z_dim) # FILL IN CODE HERE
    # decoder part
    self.fc4 = nn.Linear(z_dim, h_dim2) # FILL IN CODE HERE
    self.fc5 = nn.Linear(h_dim2, h_dim1) # FILL IN CODE HERE
    self.fc6 = nn.Linear(h_dim1, x_dim) # FILL IN CODE HERE

  def encoder(self, x):
    h = F.relu(self.fc1(x.flatten(start_dim=1))) # FILL IN CODE HERE
    h = F.relu(self.fc2(h)) # FILL IN CODE HERE
    return self.fc3(h) # FILL IN CODE HERE
  def decoder(self, z):
    h = F.relu(self.fc4(z)) # FILL IN CODE HERE
    h = F.relu(self.fc5(h)) # FILL IN CODE HERE
    return F.sigmoid(self.fc6(h)).view(-1, self.n_channels, self.n_rows, self.n_cols) # FILL IN CODE HERE
  def forward(self, x):
    y = self.decoder(self.encoder(x)) # FILL IN CODE HERE
    return(y)
  def loss_function(self,x, y):
    mse_loss = F.mse_loss(y, x) # FILL IN CODE HERE
    return torch.mean(mse_loss)

# %%
# create model
ae_dim_1 = 512
ae_dim_2 = 256
z_dim = 10
ae_model = AE(x_dim=n_pixels, h_dim1= ae_dim_1, h_dim2=ae_dim_2, z_dim=z_dim,n_rows=n_rows,n_cols=n_cols,n_channels=n_channels)
ae_optimizer = optim.Adam(ae_model.parameters())

# %% [markdown]
# Now, define a generic function to train the model for one epoch

# %%
def train_ae(ae_model,data_train_loader,epoch):
	train_loss = 0
	for batch_idx, (data, _) in enumerate(data_train_loader):
		ae_optimizer.zero_grad()

		y = ae_model(data) # FILL IN CODE HERE
		loss_ae = ae_model.loss_function(data, y) # FILL IN CODE HERE

		loss_ae.backward()
		train_loss += loss_ae.item()
		ae_optimizer.step()

		if batch_idx % 100 == 0:
			print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
				epoch, batch_idx * len(data), len(data_train_loader.dataset),
				100. * batch_idx / len(data_train_loader), loss_ae.item() / len(data)))
	print('====> Epoch: {} Average loss: {:.4f}'.format(epoch, train_loss / len(data_train_loader.dataset)))

# %% [markdown]
# We define a function to carry out testing on the autoencoder model

# %%
for epoch in range(0, n_epochs):
  train_ae(ae_model,mnist_train_loader,epoch)
# Out:
# Train Epoch: 0 [0/1000 (0%)]	Loss: 0.001800
# ====> Epoch: 0 Average loss: 0.0014
# Train Epoch: 1 [0/1000 (0%)]	Loss: 0.000710
# ====> Epoch: 1 Average loss: 0.0006
# Train Epoch: 2 [0/1000 (0%)]	Loss: 0.000625
# ====> Epoch: 2 Average loss: 0.0006
# Train Epoch: 3 [0/1000 (0%)]	Loss: 0.000578
# ====> Epoch: 3 Average loss: 0.0005
# Train Epoch: 4 [0/1000 (0%)]	Loss: 0.000576
# ====> Epoch: 4 Average loss: 0.0005
# Train Epoch: 5 [0/1000 (0%)]	Loss: 0.000586
# ====> Epoch: 5 Average loss: 0.0005
# Train Epoch: 6 [0/1000 (0%)]	Loss: 0.000575
# ====> Epoch: 6 Average loss: 0.0005
# Train Epoch: 7 [0/1000 (0%)]	Loss: 0.000545
# ====> Epoch: 7 Average loss: 0.0005
# Train Epoch: 8 [0/1000 (0%)]	Loss: 0.000531
# ====> Epoch: 8 Average loss: 0.0005
# Train Epoch: 9 [0/1000 (0%)]	Loss: 0.000525
# ====> Epoch: 9 Average loss: 0.0005
# Train Epoch: 10 [0/1000 (0%)]	Loss: 0.000483
# ====> Epoch: 10 Average loss: 0.0004
# Train Epoch: 11 [0/1000 (0%)]	Loss: 0.000472
# ====> Epoch: 11 Average loss: 0.0004
# Train Epoch: 12 [0/1000 (0%)]	Loss: 0.000478
# ====> Epoch: 12 Average loss: 0.0004
# Train Epoch: 13 [0/1000 (0%)]	Loss: 0.000444
# ====> Epoch: 13 Average loss: 0.0004
# Train Epoch: 14 [0/1000 (0%)]	Loss: 0.000409
# ====> Epoch: 14 Average loss: 0.0004
# Train Epoch: 15 [0/1000 (0%)]	Loss: 0.000404
# ====> Epoch: 15 Average loss: 0.0004
# Train Epoch: 16 [0/1000 (0%)]	Loss: 0.000409
# ====> Epoch: 16 Average loss: 0.0003
# Train Epoch: 17 [0/1000 (0%)]	Loss: 0.000379
# ====> Epoch: 17 Average loss: 0.0003
# Train Epoch: 18 [0/1000 (0%)]	Loss: 0.000364
# ====> Epoch: 18 Average loss: 0.0003
# Train Epoch: 19 [0/1000 (0%)]	Loss: 0.000347
# ====> Epoch: 19 Average loss: 0.0003
# Train Epoch: 20 [0/1000 (0%)]	Loss: 0.000335
# ====> Epoch: 20 Average loss: 0.0003
# Train Epoch: 21 [0/1000 (0%)]	Loss: 0.000316
# ====> Epoch: 21 Average loss: 0.0003
# Train Epoch: 22 [0/1000 (0%)]	Loss: 0.000295
# ====> Epoch: 22 Average loss: 0.0003
# Train Epoch: 23 [0/1000 (0%)]	Loss: 0.000283
# ====> Epoch: 23 Average loss: 0.0003
# Train Epoch: 24 [0/1000 (0%)]	Loss: 0.000279
# ====> Epoch: 24 Average loss: 0.0003
# Train Epoch: 25 [0/1000 (0%)]	Loss: 0.000273
# ====> Epoch: 25 Average loss: 0.0002
# Train Epoch: 26 [0/1000 (0%)]	Loss: 0.000259
# ====> Epoch: 26 Average loss: 0.0002
# Train Epoch: 27 [0/1000 (0%)]	Loss: 0.000255
# ====> Epoch: 27 Average loss: 0.0002
# Train Epoch: 28 [0/1000 (0%)]	Loss: 0.000254
# ====> Epoch: 28 Average loss: 0.0002
# Train Epoch: 29 [0/1000 (0%)]	Loss: 0.000244
# ====> Epoch: 29 Average loss: 0.0002
# Train Epoch: 30 [0/1000 (0%)]	Loss: 0.000246
# ====> Epoch: 30 Average loss: 0.0002
# Train Epoch: 31 [0/1000 (0%)]	Loss: 0.000231
# ====> Epoch: 31 Average loss: 0.0002
# Train Epoch: 32 [0/1000 (0%)]	Loss: 0.000223
# ====> Epoch: 32 Average loss: 0.0002
# Train Epoch: 33 [0/1000 (0%)]	Loss: 0.000215
# ====> Epoch: 33 Average loss: 0.0002
# Train Epoch: 34 [0/1000 (0%)]	Loss: 0.000218
# ====> Epoch: 34 Average loss: 0.0002
# Train Epoch: 35 [0/1000 (0%)]	Loss: 0.000214
# ====> Epoch: 35 Average loss: 0.0002
# Train Epoch: 36 [0/1000 (0%)]	Loss: 0.000205
# ====> Epoch: 36 Average loss: 0.0002
# Train Epoch: 37 [0/1000 (0%)]	Loss: 0.000214
# ====> Epoch: 37 Average loss: 0.0002
# Train Epoch: 38 [0/1000 (0%)]	Loss: 0.000197
# ====> Epoch: 38 Average loss: 0.0002
# Train Epoch: 39 [0/1000 (0%)]	Loss: 0.000217
# ====> Epoch: 39 Average loss: 0.0002
# Train Epoch: 40 [0/1000 (0%)]	Loss: 0.000194
# ====> Epoch: 40 Average loss: 0.0002
# Train Epoch: 41 [0/1000 (0%)]	Loss: 0.000191
# ====> Epoch: 41 Average loss: 0.0002
# Train Epoch: 42 [0/1000 (0%)]	Loss: 0.000195
# ====> Epoch: 42 Average loss: 0.0002
# Train Epoch: 43 [0/1000 (0%)]	Loss: 0.000189
# ====> Epoch: 43 Average loss: 0.0002
# Train Epoch: 44 [0/1000 (0%)]	Loss: 0.000199
# ====> Epoch: 44 Average loss: 0.0002
# Train Epoch: 45 [0/1000 (0%)]	Loss: 0.000198
# ====> Epoch: 45 Average loss: 0.0002
# Train Epoch: 46 [0/1000 (0%)]	Loss: 0.000174
# ====> Epoch: 46 Average loss: 0.0002
# Train Epoch: 47 [0/1000 (0%)]	Loss: 0.000177
# ====> Epoch: 47 Average loss: 0.0002
# Train Epoch: 48 [0/1000 (0%)]	Loss: 0.000180
# ====> Epoch: 48 Average loss: 0.0002
# Train Epoch: 49 [0/1000 (0%)]	Loss: 0.000174
# ====> Epoch: 49 Average loss: 0.0002
# Train Epoch: 50 [0/1000 (0%)]	Loss: 0.000167
# ====> Epoch: 50 Average loss: 0.0002
# Train Epoch: 51 [0/1000 (0%)]	Loss: 0.000168
# ====> Epoch: 51 Average loss: 0.0002
# Train Epoch: 52 [0/1000 (0%)]	Loss: 0.000159
# ====> Epoch: 52 Average loss: 0.0002
# Train Epoch: 53 [0/1000 (0%)]	Loss: 0.000167
# ====> Epoch: 53 Average loss: 0.0002
# Train Epoch: 54 [0/1000 (0%)]	Loss: 0.000171
# ====> Epoch: 54 Average loss: 0.0001
# Train Epoch: 55 [0/1000 (0%)]	Loss: 0.000157
# ====> Epoch: 55 Average loss: 0.0001
# Train Epoch: 56 [0/1000 (0%)]	Loss: 0.000164
# ====> Epoch: 56 Average loss: 0.0001
# Train Epoch: 57 [0/1000 (0%)]	Loss: 0.000158
# ====> Epoch: 57 Average loss: 0.0001
# Train Epoch: 58 [0/1000 (0%)]	Loss: 0.000164
# ====> Epoch: 58 Average loss: 0.0001
# Train Epoch: 59 [0/1000 (0%)]	Loss: 0.000159
# ====> Epoch: 59 Average loss: 0.0001
# Train Epoch: 60 [0/1000 (0%)]	Loss: 0.000154
# ====> Epoch: 60 Average loss: 0.0001
# Train Epoch: 61 [0/1000 (0%)]	Loss: 0.000140
# ====> Epoch: 61 Average loss: 0.0001
# Train Epoch: 62 [0/1000 (0%)]	Loss: 0.000150
# ====> Epoch: 62 Average loss: 0.0001
# Train Epoch: 63 [0/1000 (0%)]	Loss: 0.000139
# ====> Epoch: 63 Average loss: 0.0001
# Train Epoch: 64 [0/1000 (0%)]	Loss: 0.000142
# ====> Epoch: 64 Average loss: 0.0001
# Train Epoch: 65 [0/1000 (0%)]	Loss: 0.000150
# ====> Epoch: 65 Average loss: 0.0001
# Train Epoch: 66 [0/1000 (0%)]	Loss: 0.000142
# ====> Epoch: 66 Average loss: 0.0001
# Train Epoch: 67 [0/1000 (0%)]	Loss: 0.000134
# ====> Epoch: 67 Average loss: 0.0001
# Train Epoch: 68 [0/1000 (0%)]	Loss: 0.000140
# ====> Epoch: 68 Average loss: 0.0001
# Train Epoch: 69 [0/1000 (0%)]	Loss: 0.000126
# ====> Epoch: 69 Average loss: 0.0001
# Train Epoch: 70 [0/1000 (0%)]	Loss: 0.000131
# ====> Epoch: 70 Average loss: 0.0001
# Train Epoch: 71 [0/1000 (0%)]	Loss: 0.000125
# ====> Epoch: 71 Average loss: 0.0001
# Train Epoch: 72 [0/1000 (0%)]	Loss: 0.000136
# ====> Epoch: 72 Average loss: 0.0001
# Train Epoch: 73 [0/1000 (0%)]	Loss: 0.000124
# ====> Epoch: 73 Average loss: 0.0001
# Train Epoch: 74 [0/1000 (0%)]	Loss: 0.000131
# ====> Epoch: 74 Average loss: 0.0001
# Train Epoch: 75 [0/1000 (0%)]	Loss: 0.000126
# ====> Epoch: 75 Average loss: 0.0001
# Train Epoch: 76 [0/1000 (0%)]	Loss: 0.000139
# ====> Epoch: 76 Average loss: 0.0001
# Train Epoch: 77 [0/1000 (0%)]	Loss: 0.000137
# ====> Epoch: 77 Average loss: 0.0001
# Train Epoch: 78 [0/1000 (0%)]	Loss: 0.000124
# ====> Epoch: 78 Average loss: 0.0001
# Train Epoch: 79 [0/1000 (0%)]	Loss: 0.000118
# ====> Epoch: 79 Average loss: 0.0001
# Train Epoch: 80 [0/1000 (0%)]	Loss: 0.000126
# ====> Epoch: 80 Average loss: 0.0001
# Train Epoch: 81 [0/1000 (0%)]	Loss: 0.000123
# ====> Epoch: 81 Average loss: 0.0001
# Train Epoch: 82 [0/1000 (0%)]	Loss: 0.000121
# ====> Epoch: 82 Average loss: 0.0001
# Train Epoch: 83 [0/1000 (0%)]	Loss: 0.000119
# ====> Epoch: 83 Average loss: 0.0001
# Train Epoch: 84 [0/1000 (0%)]	Loss: 0.000112
# ====> Epoch: 84 Average loss: 0.0001
# Train Epoch: 85 [0/1000 (0%)]	Loss: 0.000120
# ====> Epoch: 85 Average loss: 0.0001
# Train Epoch: 86 [0/1000 (0%)]	Loss: 0.000110
# ====> Epoch: 86 Average loss: 0.0001
# Train Epoch: 87 [0/1000 (0%)]	Loss: 0.000112
# ====> Epoch: 87 Average loss: 0.0001
# Train Epoch: 88 [0/1000 (0%)]	Loss: 0.000112
# ====> Epoch: 88 Average loss: 0.0001
# Train Epoch: 89 [0/1000 (0%)]	Loss: 0.000114
# ====> Epoch: 89 Average loss: 0.0001
# Train Epoch: 90 [0/1000 (0%)]	Loss: 0.000112
# ====> Epoch: 90 Average loss: 0.0001
# Train Epoch: 91 [0/1000 (0%)]	Loss: 0.000108
# ====> Epoch: 91 Average loss: 0.0001
# Train Epoch: 92 [0/1000 (0%)]	Loss: 0.000101
# ====> Epoch: 92 Average loss: 0.0001
# Train Epoch: 93 [0/1000 (0%)]	Loss: 0.000105
# ====> Epoch: 93 Average loss: 0.0001
# Train Epoch: 94 [0/1000 (0%)]	Loss: 0.000105
# ====> Epoch: 94 Average loss: 0.0001
# Train Epoch: 95 [0/1000 (0%)]	Loss: 0.000107
# ====> Epoch: 95 Average loss: 0.0001
# Train Epoch: 96 [0/1000 (0%)]	Loss: 0.000099
# ====> Epoch: 96 Average loss: 0.0001
# Train Epoch: 97 [0/1000 (0%)]	Loss: 0.000100
# ====> Epoch: 97 Average loss: 0.0001
# Train Epoch: 98 [0/1000 (0%)]	Loss: 0.000103
# ====> Epoch: 98 Average loss: 0.0001
# Train Epoch: 99 [0/1000 (0%)]	Loss: 0.000097
# ====> Epoch: 99 Average loss: 0.0001
# Train Epoch: 100 [0/1000 (0%)]	Loss: 0.000102
# ====> Epoch: 100 Average loss: 0.0001
# Train Epoch: 101 [0/1000 (0%)]	Loss: 0.000090
# ====> Epoch: 101 Average loss: 0.0001
# Train Epoch: 102 [0/1000 (0%)]	Loss: 0.000097
# ====> Epoch: 102 Average loss: 0.0001
# Train Epoch: 103 [0/1000 (0%)]	Loss: 0.000098
# ====> Epoch: 103 Average loss: 0.0001
# Train Epoch: 104 [0/1000 (0%)]	Loss: 0.000098
# ====> Epoch: 104 Average loss: 0.0001
# Train Epoch: 105 [0/1000 (0%)]	Loss: 0.000092
# ====> Epoch: 105 Average loss: 0.0001
# Train Epoch: 106 [0/1000 (0%)]	Loss: 0.000097
# ====> Epoch: 106 Average loss: 0.0001
# Train Epoch: 107 [0/1000 (0%)]	Loss: 0.000092
# ====> Epoch: 107 Average loss: 0.0001
# Train Epoch: 108 [0/1000 (0%)]	Loss: 0.000095
# ====> Epoch: 108 Average loss: 0.0001
# Train Epoch: 109 [0/1000 (0%)]	Loss: 0.000092
# ====> Epoch: 109 Average loss: 0.0001
# Train Epoch: 110 [0/1000 (0%)]	Loss: 0.000093
# ====> Epoch: 110 Average loss: 0.0001
# Train Epoch: 111 [0/1000 (0%)]	Loss: 0.000089
# ====> Epoch: 111 Average loss: 0.0001
# Train Epoch: 112 [0/1000 (0%)]	Loss: 0.000080
# ====> Epoch: 112 Average loss: 0.0001
# Train Epoch: 113 [0/1000 (0%)]	Loss: 0.000083
# ====> Epoch: 113 Average loss: 0.0001
# Train Epoch: 114 [0/1000 (0%)]	Loss: 0.000089
# ====> Epoch: 114 Average loss: 0.0001
# Train Epoch: 115 [0/1000 (0%)]	Loss: 0.000085
# ====> Epoch: 115 Average loss: 0.0001
# Train Epoch: 116 [0/1000 (0%)]	Loss: 0.000089
# ====> Epoch: 116 Average loss: 0.0001
# Train Epoch: 117 [0/1000 (0%)]	Loss: 0.000085
# ====> Epoch: 117 Average loss: 0.0001
# Train Epoch: 118 [0/1000 (0%)]	Loss: 0.000087
# ====> Epoch: 118 Average loss: 0.0001
# Train Epoch: 119 [0/1000 (0%)]	Loss: 0.000079
# ====> Epoch: 119 Average loss: 0.0001
# Train Epoch: 120 [0/1000 (0%)]	Loss: 0.000081
# ====> Epoch: 120 Average loss: 0.0001
# Train Epoch: 121 [0/1000 (0%)]	Loss: 0.000082
# ====> Epoch: 121 Average loss: 0.0001
# Train Epoch: 122 [0/1000 (0%)]	Loss: 0.000077
# ====> Epoch: 122 Average loss: 0.0001
# Train Epoch: 123 [0/1000 (0%)]	Loss: 0.000083
# ====> Epoch: 123 Average loss: 0.0001
# Train Epoch: 124 [0/1000 (0%)]	Loss: 0.000072
# ====> Epoch: 124 Average loss: 0.0001
# Train Epoch: 125 [0/1000 (0%)]	Loss: 0.000081
# ====> Epoch: 125 Average loss: 0.0001
# Train Epoch: 126 [0/1000 (0%)]	Loss: 0.000081
# ====> Epoch: 126 Average loss: 0.0001
# Train Epoch: 127 [0/1000 (0%)]	Loss: 0.000076
# ====> Epoch: 127 Average loss: 0.0001
# Train Epoch: 128 [0/1000 (0%)]	Loss: 0.000080
# ====> Epoch: 128 Average loss: 0.0001
# Train Epoch: 129 [0/1000 (0%)]	Loss: 0.000077
# ====> Epoch: 129 Average loss: 0.0001
# Train Epoch: 130 [0/1000 (0%)]	Loss: 0.000079
# ====> Epoch: 130 Average loss: 0.0001
# Train Epoch: 131 [0/1000 (0%)]	Loss: 0.000069
# ====> Epoch: 131 Average loss: 0.0001
# Train Epoch: 132 [0/1000 (0%)]	Loss: 0.000079
# ====> Epoch: 132 Average loss: 0.0001
# Train Epoch: 133 [0/1000 (0%)]	Loss: 0.000080
# ====> Epoch: 133 Average loss: 0.0001
# Train Epoch: 134 [0/1000 (0%)]	Loss: 0.000077
# ====> Epoch: 134 Average loss: 0.0001
# Train Epoch: 135 [0/1000 (0%)]	Loss: 0.000075
# ====> Epoch: 135 Average loss: 0.0001
# Train Epoch: 136 [0/1000 (0%)]	Loss: 0.000073
# ====> Epoch: 136 Average loss: 0.0001
# Train Epoch: 137 [0/1000 (0%)]	Loss: 0.000068
# ====> Epoch: 137 Average loss: 0.0001
# Train Epoch: 138 [0/1000 (0%)]	Loss: 0.000074
# ====> Epoch: 138 Average loss: 0.0001
# Train Epoch: 139 [0/1000 (0%)]	Loss: 0.000070
# ====> Epoch: 139 Average loss: 0.0001
# Train Epoch: 140 [0/1000 (0%)]	Loss: 0.000073
# ====> Epoch: 140 Average loss: 0.0001
# Train Epoch: 141 [0/1000 (0%)]	Loss: 0.000071
# ====> Epoch: 141 Average loss: 0.0001
# Train Epoch: 142 [0/1000 (0%)]	Loss: 0.000073
# ====> Epoch: 142 Average loss: 0.0001
# Train Epoch: 143 [0/1000 (0%)]	Loss: 0.000067
# ====> Epoch: 143 Average loss: 0.0001
# Train Epoch: 144 [0/1000 (0%)]	Loss: 0.000069
# ====> Epoch: 144 Average loss: 0.0001
# Train Epoch: 145 [0/1000 (0%)]	Loss: 0.000072
# ====> Epoch: 145 Average loss: 0.0001
# Train Epoch: 146 [0/1000 (0%)]	Loss: 0.000069
# ====> Epoch: 146 Average loss: 0.0001
# Train Epoch: 147 [0/1000 (0%)]	Loss: 0.000072
# ====> Epoch: 147 Average loss: 0.0001
# Train Epoch: 148 [0/1000 (0%)]	Loss: 0.000069
# ====> Epoch: 148 Average loss: 0.0001
# Train Epoch: 149 [0/1000 (0%)]	Loss: 0.000066
# ====> Epoch: 149 Average loss: 0.0001

# %%
def display_images(imgs):

  r = 1
  c = imgs.shape[0]
  fig, axs = plt.subplots(r, c)
  for j in range(c):
    #black and white images
    axs[j].imshow(pytorch_to_numpy(imgs[j, 0,:,:]), cmap='gray')
    axs[j].axis('off')
  plt.show()

def display_ae_images(ae_model, test_imgs):
  n_images = 5
  idx = np.random.randint(0, test_imgs.shape[0], n_images)
  test_imgs = test_imgs[idx,:,:,:]
  print(test_imgs.shape)

  #get output images
  output_imgs = pytorch_to_numpy(ae_model.forward( test_imgs ))
  print(output_imgs.shape)

  r = 2
  c = n_images
  fig, axs = plt.subplots(r, c)
  for j in range(c):
    #black and white images
    axs[0,j].imshow(test_imgs[j, 0,:,:], cmap='gray')
    axs[0,j].axis('off')
    axs[1,j].imshow(output_imgs[j, 0,:,:], cmap='gray')
    axs[1,j].axis('off')
  plt.show()

# %%
test_imgs = next(iter(mnist_train_loader))[0]
display_ae_images(ae_model, test_imgs)
# Out:
# torch.Size([5, 1, 28, 28])
# (5, 1, 28, 28)

# %% [markdown]
# __Question__ Are you satisfied with the results, do they look good ?

# %% [markdown]
# __Your answer:__ Yes because we trained over a large number of epochs. The images are quite simple so maybe more complex models might not improve much. If we had fewer epochs maybe it would have been bad.

# %% [markdown]
# ## 2/ Two simple generative models
#
# In this section, we consider two naïve approaches to creating generative models. The general idea is the following:
#
# - train an autoencoder
# - estimate different statistics (average, variance) of the data in the latent space
# - using these statistics, define a model based on a Gaussian distribution
# - generate data with this distribution
#
# We will consider these two situations :
#
# - a multivariate Gaussian distribution with __diagonal covariance matrix__ (each latent component is an independent random variable). This requires the average and variance in each latent component
# - a multivariate Gaussian distribution with __non-diagonal covariance matrix__. This requires the average and covariance matrix of the latent components
#
# Obviously, since this is done _a posteriori_ after training the autoencoder, there is nothing which guarantees that the latent codes do indeed follow a Gaussian distribution. Our goal will be to verify that Variational Autoencoders indeed produce better results than such naïve approaches.

# %% [markdown]
# ## 2.0 Defining and generating random Gaussian latent codes
#
# Let $z$ be a latent code and $d$ the dimension of the latent space (called ``z_dim`` in the code). We suppose that the $z$'s follow a multivariate Gaussian distribution, written as:
#
# \begin{equation}
# z \sim \mathcal{N}\left(
# \mu,
# \bf{C}
# \right),
# \end{equation}
# where $\mu$ and $\bf{C}$ are the average vector and covariance matrix of the Gaussian distribution. To define such a generative model, we must therefore determine $\mu$ and $\bf{C}$. Once this is done, we can generate a random Gaussian latent code in the following manner:
#
# \begin{equation}
# z = \mu + {\bf{L}} \varepsilon,
# \end{equation}
# where $\varepsilon$ is a random vector drawn from a multivariate normal distribution ($\mu=0$ and ${\bf{C}} = \text{Id}$), and $\bf{L}$ is the Cholesky decomposition of the positive semi-definite covariance matrix. In other words:
#
# \begin{equation}
# {\bf{C}} = {\bf{L}}{\bf{L}^T}.
# \end{equation}
#
# This gives a simple method of producing a multivariate Gaussian random variable.

# %% [markdown]
# ## 2.1/ A Gaussian model with diagonal covariance
#
# The first naïve model is  defined in this first case as:
#
# - $\bf{\mu}=\left[\mu_0, \mu_1, \cdots, \mu_{d-1}\right]^T$
# - $
#   \bf{C} = \begin{pmatrix}
# \sigma_0^2 & 0 & \cdots & 0 \\
# 0 & \sigma_1^2 & \cdots & 0 \\
# \vdots & \ddots & \ddots & \vdots \\
# 0 & 0 & \cdots & \sigma_{d-1}^2
# \end{pmatrix}$
#
# In this situation, therefore, the matrix $\bf{L}$ can be calculated quite simply, as:
# - $
#   \bf{L} = \begin{pmatrix}
# \sigma_0 & 0 & \cdots & 0 \\
# 0 & \sigma_1 & \cdots & 0 \\
# \vdots & \ddots & \ddots & \vdots \\
# 0 & 0 & \cdots & \sigma_{d-1}
# \end{pmatrix}$
#
# In the next cell, calculate the empirical average and variances over a certain number of batches:

# %%
n_batches = np.floor( len(mnist_train_loader.dataset.indices)/batch_size ).astype(int)

z_average = torch.zeros(n_batches,ae_model.z_dim)
z_sigma = torch.zeros(n_batches,ae_model.z_dim)

for batch_idx, (data, _) in enumerate(mnist_train_loader):
  z = ae_model.encoder(data)
  z_average[batch_idx,:] = torch.mean(z, axis = 0) #FILL IN CODE HERE
  z_sigma[batch_idx,:] = torch.std(z, axis=0)# FILL IN CODE HERE

z_average = torch.mean(z, axis=0) # FILL IN CODE HERE
z_sigma = torch.mean(z_sigma, axis=0) # FILL IN CODE HERE

print("Average of latent codes:",z_average)
print("Standard deviation of latent codes:",z_sigma)
# Out:
# Average of latent codes: tensor([  1.8781,   7.9656,  -0.8440,   1.1542, -11.7744,  -3.5183,   8.4674,
#           8.4098,  -3.2010,  13.1200], grad_fn=<MeanBackward1>)
# Standard deviation of latent codes: tensor([ 6.3923,  7.1570, 10.0552, 10.6278,  8.4387,  8.0240,  7.8145,  9.3768,
#          9.6125,  8.0851], grad_fn=<MeanBackward1>)

# %% [markdown]
# Now, in the next cell generate data with this simple generative model using the approach described above. Display these images with the ``display_images`` function.
#
# __NB__ You do not actually have to define the matrix $\bf{L}$ in this case, an element-wise multiplication of two (properly chosen) vectors will suffice. To generate multivariate normal random variables you can use the following Pytorch function:
#
# - ```torch.randn```

# %%
def generate_images_diagonal_gaussian(ae_model,z_average,z_sigma,n_images = 5):

  epsilon = torch.randn(n_images, ae_model.z_dim) # FILL IN CODE HERE
  z_generated = z_average + z_sigma*epsilon # FILL IN CODE HERE
  imgs_generated = ae_model.decoder(z_generated) # FILL IN CODE HERE
  return(imgs_generated)

imgs_generated = generate_images_diagonal_gaussian(ae_model,z_average,z_sigma,n_images=5)
display_images(imgs_generated)

# %% [markdown]
# As you should be able to see, these results are not that good. Let's try a slightly more sophisticated model.

# %% [markdown]
# ## 2.1 Non-diagonal Gaussian model
#
# The second model uses a non-diagonal covariance matrix $\bf{C}$ in the multivariate Gaussian distribution. In the next cell, calculate the average and covariance matrix over several batches of latent codes.
#
# __NB__ You can use the ```torch.cov``` function. Make sure to put the data in the right format for this (see documentation : https://pytorch.org/docs/stable/generated/torch.cov.html).

# %%
n_batches = np.floor( len(mnist_train_loader.dataset.indices)/batch_size ).astype(int)

z_average = torch.zeros(n_batches,ae_model.z_dim)
z_covariance = torch.zeros(n_batches,ae_model.z_dim,ae_model.z_dim)

for batch_idx, (data, _) in enumerate(mnist_train_loader):
  z = ae_model.encoder(data)
  z_average[batch_idx,:] = torch.mean(z, axis = 0) # FILL IN CODE HERE
  z_covariance[batch_idx,:,:] = torch.cov(z.T) # FILL IN CODE HERE

z_average = torch.mean(z_average, axis = 0) # FILL IN CODE HERE
z_covariance = torch.mean(z_covariance, axis=0) # FILL IN CODE HERE

print("Average of latent codes:",z_average)
print("Covariance matrix of latent codes:",z_covariance)
# Out:
# Average of latent codes: tensor([  2.2441,   7.8481,  -0.7960,   0.6917, -10.8406,  -3.8683,   7.2754,
#           7.5779,  -3.2273,  11.4522], grad_fn=<MeanBackward1>)
# Covariance matrix of latent codes: tensor([[ 40.8752,   4.4782,  13.1594,   1.5856, -14.6002,  12.0418,  10.8956,
#           -3.9552,  21.5662, -25.7779],
#         [  4.4782,  51.5253, -18.9055,  29.3120,  -9.7269,  -5.4003,  -0.7410,
#           38.2878,   6.1025,  12.5404],
#         [ 13.1594, -18.9055,  99.1272, -30.5650,  44.4012,  23.9345,  14.5680,
#          -29.0962, -26.3898,   0.6832],
#         [  1.5856,  29.3120, -30.5650, 112.3441,  -0.9873, -13.1548, -30.6472,
#           10.1199,  -1.5854,  -7.7009],
#         [-14.6002,  -9.7269,  44.4012,  -0.9873,  71.0513,  -1.2105,  -2.4887,
#            0.8144,  -5.7279,   9.1757],
#         [ 12.0418,  -5.4003,  23.9345, -13.1548,  -1.2105,  62.6982,  30.6826,
#           -4.3122,  -9.7987,  -4.9176],
#         [ 10.8956,  -0.7410,  14.5680, -30.6472,  -2.4887,  30.6826,  60.2845,
#           17.5387,  16.5166,   5.4413],
#         [ -3.9552,  38.2878, -29.0962,  10.1199,   0.8144,  -4.3122,  17.5387,
#           87.5844,  16.0898,  20.9192],
#         [ 21.5662,   6.1025, -26.3898,  -1.5854,  -5.7279,  -9.7987,  16.5166,
#           16.0898,  91.6484, -25.9844],
#         [-25.7779,  12.5404,   0.6832,  -7.7009,   9.1757,  -4.9176,   5.4413,
#           20.9192, -25.9844,  62.7725]], grad_fn=<MeanBackward1>)

# %% [markdown]
# Now, generate some samples with this distribution. In this case, you will actually have to calculate the Cholesky decomposition and find $\bf{L}$. For this, you can use
#
# - ```torch.linalg.cholesky```
#
# In this model, you will need to carry out matrix multiplication over a batch of latent codes, which is a bit more complicated than the previous naïve model (which used element-wise vector multiplication). So you have two options:
#
# - copy the matrix $\bf{L}$ several times and carry out batch matrix multiplication
# - simply loop and carry out normal matrix multiplication to produce each image (this has the disadvantage of not taking advantage of any parallelisation, but it should not matter too much).
#
# In the first case, you can use the following functions:
#
# - ```torch.bmm```
# - ```torch.tile```
#
# Fill in the function to generate images using this model now:

# %%
def generate_images_non_diagonal_gaussian(ae_model,z_average,z_covariance,n_images = 5):

  #calcualte Cholesky decomposition of covariance matrix : C = L L^T
  # Make sure that the first dimension is the batch dimension (with batch size n_images)
  # You can use the torch.unsqueeze function for this
  L = torch.linalg.cholesky(z_covariance) # FILL IN CODE HERE

  epsilon = torch.randn(n_images, ae_model.z_dim) # FILL IN CODE HERE
  z_generated = z_average.unsqueeze(0) + epsilon @ L.T # FILL IN CODE HERE
  imgs_generated = ae_model.decoder(z_generated) # FILL IN CODE HERE
  return(imgs_generated)


imgs_generated = generate_images_non_diagonal_gaussian(ae_model,z_average,z_covariance,n_images = 5)
display_images(imgs_generated)

# %% [markdown]
# You should see some improvement, but we can do better than this. Thus, we turn to the variational autoencoder.

# %% [markdown]
# # 3/ Variational autoencoder
#
# Now, we are going to create an variational autoencoder to carry out __image generation__. Let's first recall the idea of a variational autoencoder
#
# ## Main idea
#
# The main idea is to create an autoencoder whose latent codes follow a certain distribution (a Gaussian distribution in practice). This is done with two tools :
#
# - A specific architecture, where the encoder produces the average and variance of the latent codes
# - A specially designed loss function
#
# Once the VAE is trained, it is possible to sample in the latent space by producing random normal variables and simply decoding.
#
# ## Architecture
#
# The architecture of the VAE model is as follows:
#
# The encoder consists of:
#
# Encoder :
# - Flatten input
# - Dense layer $+$ ReLU
# - Dense layer $+$ ReLU
# - Dense layer (no non-linarity) to produce the average, Dense layer (no non-linarity) to produce the variance (these last two layers are in parallel)
#
# Decoder :
# - Dense layer $+$ ReLU
# - Dense layer $+$ ReLU
# - Dense layer $+$ Sigmoid Activation
# - Reshape, to size $28\times 28\times 1$
#
#
# ## Variational Autoencoder loss
#
# Recall that for the VAE, the loss function is in fact a function to __maximise__. In fact, for implementation, you will see that it is easier to __minimise__ $-\mathcal{L}$.
#
# In the case of an image which is represented by a set of __Bernoulli__ variables (which is relevant for mnist), the original loss function (to maximise) is written :
#
#
# \begin{align}
# \mathcal{L} &= \log\left(p_\theta(x|z)\right) - KL\left( q_\phi(z|x) \; || \; p_\theta(z)\right) \\
#     &= \left(\sum_{i} x_i \log y_i + (1-x_i) \log (1-y_i)\right) - \left(\frac{1}{2} \sum_j \left( \sigma_j^2 + \mu_j^2 - \log \sigma_j^2 -1 \right)\right)
# \end{align}
#
#
# where $i$ is summed over the image pixels, and $j$ is summed over the elements of the latent space. $\sigma_j^2$ is the $j$th element of the latent space variance, and $\mu_j$ is the $j$th element of the latent space mean.
#
# The left part of the loss (reconstruction error) can be implemented simply as the binary cross-entropy between the input x and the output y. Since we are __maximising__ $-$[binary cross-entropy] (look at the formula), this is equivalent to minimising the binary cross-entropy.
#
# For the right part of the equation (KL divergence), you need to implement it manually.
#
# The final loss is the average, over the batch size, of the sum of the reconstruction error (left part) and the KL divergence (right part). Be careful, in the formula, the sums over $i$ and $j$ are over the number of pixels and the number of latent elements, respectively. To achieve a sum rather than an average, you can use ```torch.nn.BCELoss(reduction='sum')()```, and the ```torch.sum()``` functions.
#
# As in the case of the normal autoencoder, you will need to flatten and then reshape the tensors at the beginning/end of the network.

# %%
class VAE(torch.nn.Module ):
  def __init__(self, x_dim, h_dim1, h_dim2, z_dim,n_rows,n_cols,n_channels):
    super(VAE, self).__init__()

    self.n_rows = n_rows
    self.n_cols = n_cols
    self.n_channels = n_channels
    self.n_pixels = (self.n_rows)*(self.n_cols)
    self.z_dim = z_dim

    # encoder part
    self.fc1 = torch.nn.Linear(x_dim, h_dim1) # FILL IN CODE HERE
    self.fc2 = torch.nn.Linear(h_dim1, h_dim2) # FILL IN CODE HERE
    self.fc31 = torch.nn.Linear(h_dim2, z_dim) # FILL IN CODE HERE
    self.fc32 = torch.nn.Linear(h_dim2, z_dim) # FILL IN CODE HERE
    # decoder part
    self.fc4 = torch.nn.Linear(z_dim, h_dim2) # FILL IN CODE HERE
    self.fc5 = torch.nn.Linear(h_dim2, h_dim1) # FILL IN CODE HERE
    self.fc6 = torch.nn.Linear(h_dim1, x_dim) # FILL IN CODE HERE

  def encoder(self, x):
    x = x.flatten(start_dim=1)
    h = torch.relu(self.fc1(x)) # FILL IN CODE HERE
    h = torch.relu(self.fc2(h)) # FILL IN CODE HERE
    return self.fc31(h), self.fc32(h) # FILL IN CODE HERE # mu, log_var
  def decoder(self, z):
    h = torch.relu(self.fc4(z)) # FILL IN CODE HERE
    h = torch.relu(self.fc5(h)) # FILL IN CODE HERE
    return torch.sigmoid(self.fc6(h)).view(-1, self.n_channels, self.n_rows, self.n_cols) # FILL IN CODE HERE

  def sampling(self, mu, log_var):
    # this function samples a Gaussian distribution, with average (mu) and standard deviation specified (using log_var)
    std =  torch.exp(0.5*log_var)# FILL IN CODE HERE
    eps = torch.randn_like(std) # FILL IN CODE HERE
    return eps.mul(std).add_(mu) # return z sample

  def forward(self, x):
    z_mu, z_log_var = self.encoder(x)
    z = self.sampling(z_mu, z_log_var)
    return self.decoder(z),z_mu, z_log_var

  def loss_function(self,x, y, mu, log_var):
    reconstruction_error = torch.nn.functional.binary_cross_entropy(y, x, reduction='sum') # FILL IN CODE HERE

    KLD = -0.5*torch.sum(1 + log_var - mu.pow(2) - log_var.exp()) # FILL IN CODE HERE


    return reconstruction_error + KLD # FILL IN CODE HERE

# %% [markdown]
# Now, create the model (similarly as above)

# %%
# create model
vae_dim_1 = ae_dim_1
vae_dim_2 = ae_dim_2
vae_model = VAE(x_dim=n_pixels, h_dim1= vae_dim_1, h_dim2=vae_dim_2, z_dim=z_dim,n_rows=n_rows,n_cols=n_cols,n_channels=n_channels)
vae_optimizer = optim.Adam(vae_model.parameters())

# %% [markdown]
# Finally, train the model. First modify the training function to the case of the vae.

# %%
def train_vae(vae_model,data_train_loader,epoch):
  train_loss = 0
  for batch_idx, (data, _) in enumerate(data_train_loader):
    vae_optimizer.zero_grad()

    y, z_mu, z_log_var = vae_model(data)# FILL IN CODE HERE
    loss_vae = vae_model.loss_function(data, y, z_mu, z_log_var) # FILL IN CODE HERE
    loss_vae.backward()
    train_loss += loss_vae.item()
    vae_optimizer.step()

    if batch_idx % 100 == 0:
      print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
      epoch, batch_idx * len(data), len(data_train_loader.dataset),
      100. * batch_idx / len(data_train_loader), loss_vae.item() / len(data)))
  print('====> Epoch: {} Average loss: {:.4f}'.format(epoch, train_loss / len(data_train_loader.dataset)))

# %%
# now train the model
for epoch in range(0, n_epochs):
  train_vae(vae_model,mnist_train_loader,epoch)
# Out:
# Train Epoch: 0 [0/1000 (0%)]	Loss: 544.314636
# ====> Epoch: 0 Average loss: 410.9751
# Train Epoch: 1 [0/1000 (0%)]	Loss: 290.341919
# ====> Epoch: 1 Average loss: 238.2897
# Train Epoch: 2 [0/1000 (0%)]	Loss: 222.981262
# ====> Epoch: 2 Average loss: 201.4716
# Train Epoch: 3 [0/1000 (0%)]	Loss: 216.681656
# ====> Epoch: 3 Average loss: 191.2006
# Train Epoch: 4 [0/1000 (0%)]	Loss: 204.634827
# ====> Epoch: 4 Average loss: 189.0321
# Train Epoch: 5 [0/1000 (0%)]	Loss: 215.493805
# ====> Epoch: 5 Average loss: 188.1525
# Train Epoch: 6 [0/1000 (0%)]	Loss: 206.999146
# ====> Epoch: 6 Average loss: 185.8774
# Train Epoch: 7 [0/1000 (0%)]	Loss: 202.316193
# ====> Epoch: 7 Average loss: 184.4897
# Train Epoch: 8 [0/1000 (0%)]	Loss: 204.027237
# ====> Epoch: 8 Average loss: 184.9586
# Train Epoch: 9 [0/1000 (0%)]	Loss: 202.349625
# ====> Epoch: 9 Average loss: 182.8028
# Train Epoch: 10 [0/1000 (0%)]	Loss: 204.661774
# ====> Epoch: 10 Average loss: 180.6923
# Train Epoch: 11 [0/1000 (0%)]	Loss: 205.506317
# ====> Epoch: 11 Average loss: 179.6132
# Train Epoch: 12 [0/1000 (0%)]	Loss: 196.352798
# ====> Epoch: 12 Average loss: 177.7598
# Train Epoch: 13 [0/1000 (0%)]	Loss: 201.358246
# ====> Epoch: 13 Average loss: 175.7287
# Train Epoch: 14 [0/1000 (0%)]	Loss: 201.751526
# ====> Epoch: 14 Average loss: 173.9769
# Train Epoch: 15 [0/1000 (0%)]	Loss: 198.110199
# ====> Epoch: 15 Average loss: 174.2342
# Train Epoch: 16 [0/1000 (0%)]	Loss: 192.385345
# ====> Epoch: 16 Average loss: 172.5533
# Train Epoch: 17 [0/1000 (0%)]	Loss: 192.892410
# ====> Epoch: 17 Average loss: 170.5481
# Train Epoch: 18 [0/1000 (0%)]	Loss: 187.927567
# ====> Epoch: 18 Average loss: 169.8451
# Train Epoch: 19 [0/1000 (0%)]	Loss: 192.336090
# ====> Epoch: 19 Average loss: 167.5085
# Train Epoch: 20 [0/1000 (0%)]	Loss: 190.245712
# ====> Epoch: 20 Average loss: 166.2287
# Train Epoch: 21 [0/1000 (0%)]	Loss: 183.112854
# ====> Epoch: 21 Average loss: 165.3364
# Train Epoch: 22 [0/1000 (0%)]	Loss: 184.371857
# ====> Epoch: 22 Average loss: 164.3393
# Train Epoch: 23 [0/1000 (0%)]	Loss: 182.467682
# ====> Epoch: 23 Average loss: 162.2586
# Train Epoch: 24 [0/1000 (0%)]	Loss: 179.894226
# ====> Epoch: 24 Average loss: 161.3010
# Train Epoch: 25 [0/1000 (0%)]	Loss: 180.721298
# ====> Epoch: 25 Average loss: 159.9614
# Train Epoch: 26 [0/1000 (0%)]	Loss: 174.861816
# ====> Epoch: 26 Average loss: 158.5270
# Train Epoch: 27 [0/1000 (0%)]	Loss: 169.005325
# ====> Epoch: 27 Average loss: 155.9060
# Train Epoch: 28 [0/1000 (0%)]	Loss: 169.800415
# ====> Epoch: 28 Average loss: 153.0590
# Train Epoch: 29 [0/1000 (0%)]	Loss: 168.310699
# ====> Epoch: 29 Average loss: 151.7457
# Train Epoch: 30 [0/1000 (0%)]	Loss: 164.183411
# ====> Epoch: 30 Average loss: 148.5146
# Train Epoch: 31 [0/1000 (0%)]	Loss: 161.848984
# ====> Epoch: 31 Average loss: 146.7357
# Train Epoch: 32 [0/1000 (0%)]	Loss: 160.581757
# ====> Epoch: 32 Average loss: 144.7223
# Train Epoch: 33 [0/1000 (0%)]	Loss: 155.060211
# ====> Epoch: 33 Average loss: 141.7147
# Train Epoch: 34 [0/1000 (0%)]	Loss: 157.897385
# ====> Epoch: 34 Average loss: 140.3838
# Train Epoch: 35 [0/1000 (0%)]	Loss: 157.024857
# ====> Epoch: 35 Average loss: 138.7028
# Train Epoch: 36 [0/1000 (0%)]	Loss: 155.925491
# ====> Epoch: 36 Average loss: 137.3525
# Train Epoch: 37 [0/1000 (0%)]	Loss: 141.774170
# ====> Epoch: 37 Average loss: 135.9449
# Train Epoch: 38 [0/1000 (0%)]	Loss: 146.095718
# ====> Epoch: 38 Average loss: 134.7560
# Train Epoch: 39 [0/1000 (0%)]	Loss: 144.513992
# ====> Epoch: 39 Average loss: 133.7312
# Train Epoch: 40 [0/1000 (0%)]	Loss: 148.468994
# ====> Epoch: 40 Average loss: 133.5616
# Train Epoch: 41 [0/1000 (0%)]	Loss: 149.831848
# ====> Epoch: 41 Average loss: 131.7819
# Train Epoch: 42 [0/1000 (0%)]	Loss: 145.839432
# ====> Epoch: 42 Average loss: 130.3326
# Train Epoch: 43 [0/1000 (0%)]	Loss: 144.501419
# ====> Epoch: 43 Average loss: 129.9113
# Train Epoch: 44 [0/1000 (0%)]	Loss: 140.332565
# ====> Epoch: 44 Average loss: 128.7888
# Train Epoch: 45 [0/1000 (0%)]	Loss: 144.621857
# ====> Epoch: 45 Average loss: 128.2873
# Train Epoch: 46 [0/1000 (0%)]	Loss: 142.817688
# ====> Epoch: 46 Average loss: 126.0125
# Train Epoch: 47 [0/1000 (0%)]	Loss: 143.580765
# ====> Epoch: 47 Average loss: 126.5663
# Train Epoch: 48 [0/1000 (0%)]	Loss: 137.005630
# ====> Epoch: 48 Average loss: 124.8389
# Train Epoch: 49 [0/1000 (0%)]	Loss: 145.789856
# ====> Epoch: 49 Average loss: 123.8843
# Train Epoch: 50 [0/1000 (0%)]	Loss: 133.262070
# ====> Epoch: 50 Average loss: 123.2602
# Train Epoch: 51 [0/1000 (0%)]	Loss: 134.310532
# ====> Epoch: 51 Average loss: 121.4024
# Train Epoch: 52 [0/1000 (0%)]	Loss: 133.348358
# ====> Epoch: 52 Average loss: 121.5210
# Train Epoch: 53 [0/1000 (0%)]	Loss: 134.872513
# ====> Epoch: 53 Average loss: 120.0684
# Train Epoch: 54 [0/1000 (0%)]	Loss: 134.250702
# ====> Epoch: 54 Average loss: 119.4078
# Train Epoch: 55 [0/1000 (0%)]	Loss: 133.960587
# ====> Epoch: 55 Average loss: 118.9493
# Train Epoch: 56 [0/1000 (0%)]	Loss: 138.536407
# ====> Epoch: 56 Average loss: 119.1718
# Train Epoch: 57 [0/1000 (0%)]	Loss: 130.195007
# ====> Epoch: 57 Average loss: 118.1675
# Train Epoch: 58 [0/1000 (0%)]	Loss: 135.852402
# ====> Epoch: 58 Average loss: 117.4656
# Train Epoch: 59 [0/1000 (0%)]	Loss: 137.893295
# ====> Epoch: 59 Average loss: 116.6701
# Train Epoch: 60 [0/1000 (0%)]	Loss: 130.427551
# ====> Epoch: 60 Average loss: 116.4311
# Train Epoch: 61 [0/1000 (0%)]	Loss: 131.821152
# ====> Epoch: 61 Average loss: 116.0590
# Train Epoch: 62 [0/1000 (0%)]	Loss: 126.708145
# ====> Epoch: 62 Average loss: 115.1995
# Train Epoch: 63 [0/1000 (0%)]	Loss: 132.059586
# ====> Epoch: 63 Average loss: 114.9697
# Train Epoch: 64 [0/1000 (0%)]	Loss: 131.291855
# ====> Epoch: 64 Average loss: 114.3512
# Train Epoch: 65 [0/1000 (0%)]	Loss: 127.072586
# ====> Epoch: 65 Average loss: 113.7148
# Train Epoch: 66 [0/1000 (0%)]	Loss: 126.035843
# ====> Epoch: 66 Average loss: 113.5850
# Train Epoch: 67 [0/1000 (0%)]	Loss: 125.335701
# ====> Epoch: 67 Average loss: 113.0088
# Train Epoch: 68 [0/1000 (0%)]	Loss: 120.425858
# ====> Epoch: 68 Average loss: 112.9738
# Train Epoch: 69 [0/1000 (0%)]	Loss: 121.768715
# ====> Epoch: 69 Average loss: 111.9092
# Train Epoch: 70 [0/1000 (0%)]	Loss: 123.270790
# ====> Epoch: 70 Average loss: 111.5961
# Train Epoch: 71 [0/1000 (0%)]	Loss: 120.911125
# ====> Epoch: 71 Average loss: 111.8531
# Train Epoch: 72 [0/1000 (0%)]	Loss: 126.049126
# ====> Epoch: 72 Average loss: 111.7142
# Train Epoch: 73 [0/1000 (0%)]	Loss: 125.606239
# ====> Epoch: 73 Average loss: 111.1667
# Train Epoch: 74 [0/1000 (0%)]	Loss: 125.144966
# ====> Epoch: 74 Average loss: 110.5364
# Train Epoch: 75 [0/1000 (0%)]	Loss: 121.266960
# ====> Epoch: 75 Average loss: 110.0244
# Train Epoch: 76 [0/1000 (0%)]	Loss: 120.531174
# ====> Epoch: 76 Average loss: 108.8491
# Train Epoch: 77 [0/1000 (0%)]	Loss: 119.225601
# ====> Epoch: 77 Average loss: 109.4100
# Train Epoch: 78 [0/1000 (0%)]	Loss: 122.888390
# ====> Epoch: 78 Average loss: 109.0646
# Train Epoch: 79 [0/1000 (0%)]	Loss: 124.868988
# ====> Epoch: 79 Average loss: 109.3208
# Train Epoch: 80 [0/1000 (0%)]	Loss: 122.472954
# ====> Epoch: 80 Average loss: 108.1864
# Train Epoch: 81 [0/1000 (0%)]	Loss: 124.668839
# ====> Epoch: 81 Average loss: 108.1784
# Train Epoch: 82 [0/1000 (0%)]	Loss: 121.479752
# ====> Epoch: 82 Average loss: 107.7234
# Train Epoch: 83 [0/1000 (0%)]	Loss: 120.684677
# ====> Epoch: 83 Average loss: 107.5744
# Train Epoch: 84 [0/1000 (0%)]	Loss: 117.976257
# ====> Epoch: 84 Average loss: 107.0875
# Train Epoch: 85 [0/1000 (0%)]	Loss: 119.731628
# ====> Epoch: 85 Average loss: 107.1622
# Train Epoch: 86 [0/1000 (0%)]	Loss: 114.330528
# ====> Epoch: 86 Average loss: 106.8215
# Train Epoch: 87 [0/1000 (0%)]	Loss: 120.003830
# ====> Epoch: 87 Average loss: 106.3538
# Train Epoch: 88 [0/1000 (0%)]	Loss: 119.193970
# ====> Epoch: 88 Average loss: 106.3401
# Train Epoch: 89 [0/1000 (0%)]	Loss: 116.701828
# ====> Epoch: 89 Average loss: 105.7447
# Train Epoch: 90 [0/1000 (0%)]	Loss: 120.064583
# ====> Epoch: 90 Average loss: 105.6453
# Train Epoch: 91 [0/1000 (0%)]	Loss: 118.325600
# ====> Epoch: 91 Average loss: 104.9240
# Train Epoch: 92 [0/1000 (0%)]	Loss: 118.824280
# ====> Epoch: 92 Average loss: 105.2094
# Train Epoch: 93 [0/1000 (0%)]	Loss: 119.121552
# ====> Epoch: 93 Average loss: 105.0461
# Train Epoch: 94 [0/1000 (0%)]	Loss: 115.456924
# ====> Epoch: 94 Average loss: 104.3153
# Train Epoch: 95 [0/1000 (0%)]	Loss: 117.631630
# ====> Epoch: 95 Average loss: 104.2830
# Train Epoch: 96 [0/1000 (0%)]	Loss: 110.807976
# ====> Epoch: 96 Average loss: 103.5597
# Train Epoch: 97 [0/1000 (0%)]	Loss: 109.693909
# ====> Epoch: 97 Average loss: 103.9332
# Train Epoch: 98 [0/1000 (0%)]	Loss: 116.539467
# ====> Epoch: 98 Average loss: 103.4369
# Train Epoch: 99 [0/1000 (0%)]	Loss: 115.661240
# ====> Epoch: 99 Average loss: 102.7194
# Train Epoch: 100 [0/1000 (0%)]	Loss: 112.645523
# ====> Epoch: 100 Average loss: 102.8015
# Train Epoch: 101 [0/1000 (0%)]	Loss: 113.606766
# ====> Epoch: 101 Average loss: 102.3466
# Train Epoch: 102 [0/1000 (0%)]	Loss: 115.024139
# ====> Epoch: 102 Average loss: 101.9360
# Train Epoch: 103 [0/1000 (0%)]	Loss: 112.360870
# ====> Epoch: 103 Average loss: 101.7683
# Train Epoch: 104 [0/1000 (0%)]	Loss: 112.957497
# ====> Epoch: 104 Average loss: 101.2335
# Train Epoch: 105 [0/1000 (0%)]	Loss: 109.272522
# ====> Epoch: 105 Average loss: 101.6069
# Train Epoch: 106 [0/1000 (0%)]	Loss: 110.921204
# ====> Epoch: 106 Average loss: 101.2428
# Train Epoch: 107 [0/1000 (0%)]	Loss: 108.329544
# ====> Epoch: 107 Average loss: 101.0576
# Train Epoch: 108 [0/1000 (0%)]	Loss: 110.149170
# ====> Epoch: 108 Average loss: 100.6954
# Train Epoch: 109 [0/1000 (0%)]	Loss: 111.766113
# ====> Epoch: 109 Average loss: 100.4128
# Train Epoch: 110 [0/1000 (0%)]	Loss: 112.677910
# ====> Epoch: 110 Average loss: 100.0905
# Train Epoch: 111 [0/1000 (0%)]	Loss: 113.531448
# ====> Epoch: 111 Average loss: 99.8573
# Train Epoch: 112 [0/1000 (0%)]	Loss: 109.250702
# ====> Epoch: 112 Average loss: 99.3916
# Train Epoch: 113 [0/1000 (0%)]	Loss: 111.085625
# ====> Epoch: 113 Average loss: 99.7300
# Train Epoch: 114 [0/1000 (0%)]	Loss: 108.216339
# ====> Epoch: 114 Average loss: 99.5785
# Train Epoch: 115 [0/1000 (0%)]	Loss: 112.443268
# ====> Epoch: 115 Average loss: 99.3992
# Train Epoch: 116 [0/1000 (0%)]	Loss: 109.234001
# ====> Epoch: 116 Average loss: 98.7826
# Train Epoch: 117 [0/1000 (0%)]	Loss: 107.655441
# ====> Epoch: 117 Average loss: 98.6777
# Train Epoch: 118 [0/1000 (0%)]	Loss: 108.641106
# ====> Epoch: 118 Average loss: 98.6098
# Train Epoch: 119 [0/1000 (0%)]	Loss: 109.192474
# ====> Epoch: 119 Average loss: 99.3585
# Train Epoch: 120 [0/1000 (0%)]	Loss: 109.726326
# ====> Epoch: 120 Average loss: 98.3068
# Train Epoch: 121 [0/1000 (0%)]	Loss: 105.064598
# ====> Epoch: 121 Average loss: 97.8244
# Train Epoch: 122 [0/1000 (0%)]	Loss: 107.112000
# ====> Epoch: 122 Average loss: 97.8354
# Train Epoch: 123 [0/1000 (0%)]	Loss: 105.709137
# ====> Epoch: 123 Average loss: 98.0046
# Train Epoch: 124 [0/1000 (0%)]	Loss: 106.801498
# ====> Epoch: 124 Average loss: 97.2020
# Train Epoch: 125 [0/1000 (0%)]	Loss: 105.934761
# ====> Epoch: 125 Average loss: 97.3824
# Train Epoch: 126 [0/1000 (0%)]	Loss: 106.661346
# ====> Epoch: 126 Average loss: 97.3212
# Train Epoch: 127 [0/1000 (0%)]	Loss: 105.687592
# ====> Epoch: 127 Average loss: 96.6694
# Train Epoch: 128 [0/1000 (0%)]	Loss: 104.255791
# ====> Epoch: 128 Average loss: 97.0462
# Train Epoch: 129 [0/1000 (0%)]	Loss: 108.698387
# ====> Epoch: 129 Average loss: 96.5996
# Train Epoch: 130 [0/1000 (0%)]	Loss: 107.532646
# ====> Epoch: 130 Average loss: 96.6349
# Train Epoch: 131 [0/1000 (0%)]	Loss: 103.286201
# ====> Epoch: 131 Average loss: 96.1044
# Train Epoch: 132 [0/1000 (0%)]	Loss: 105.056320
# ====> Epoch: 132 Average loss: 95.6199
# Train Epoch: 133 [0/1000 (0%)]	Loss: 106.471291
# ====> Epoch: 133 Average loss: 95.9891
# Train Epoch: 134 [0/1000 (0%)]	Loss: 105.119278
# ====> Epoch: 134 Average loss: 95.6856
# Train Epoch: 135 [0/1000 (0%)]	Loss: 102.066162
# ====> Epoch: 135 Average loss: 95.4245
# Train Epoch: 136 [0/1000 (0%)]	Loss: 101.426659
# ====> Epoch: 136 Average loss: 95.6766
# Train Epoch: 137 [0/1000 (0%)]	Loss: 108.489868
# ====> Epoch: 137 Average loss: 96.2921
# Train Epoch: 138 [0/1000 (0%)]	Loss: 107.164154
# ====> Epoch: 138 Average loss: 95.1991
# Train Epoch: 139 [0/1000 (0%)]	Loss: 103.710068
# ====> Epoch: 139 Average loss: 95.0273
# Train Epoch: 140 [0/1000 (0%)]	Loss: 103.152222
# ====> Epoch: 140 Average loss: 95.3965
# Train Epoch: 141 [0/1000 (0%)]	Loss: 105.330803
# ====> Epoch: 141 Average loss: 95.0431
# Train Epoch: 142 [0/1000 (0%)]	Loss: 106.243774
# ====> Epoch: 142 Average loss: 94.8107
# Train Epoch: 143 [0/1000 (0%)]	Loss: 107.749062
# ====> Epoch: 143 Average loss: 95.0696
# Train Epoch: 144 [0/1000 (0%)]	Loss: 105.219025
# ====> Epoch: 144 Average loss: 94.5161
# Train Epoch: 145 [0/1000 (0%)]	Loss: 104.565628
# ====> Epoch: 145 Average loss: 94.2791
# Train Epoch: 146 [0/1000 (0%)]	Loss: 103.561371
# ====> Epoch: 146 Average loss: 94.5690
# Train Epoch: 147 [0/1000 (0%)]	Loss: 102.735168
# ====> Epoch: 147 Average loss: 93.8386
# Train Epoch: 148 [0/1000 (0%)]	Loss: 105.963043
# ====> Epoch: 148 Average loss: 93.8141
# Train Epoch: 149 [0/1000 (0%)]	Loss: 104.438698
# ====> Epoch: 149 Average loss: 93.7250

# %% [markdown]
# Now, generate some images with the VAE model

# %%
def generate_images_vae(vae_model,n_images = 5):

  epsilon = torch.randn(n_images, vae_model.z_dim) # FILL IN CODE HERE
  imgs_generated = vae_model.decoder(epsilon) # FILL IN CODE HERE
  return(imgs_generated)

imgs_generated = generate_images_vae(vae_model,n_images=5)
display_images(imgs_generated)

# %% [markdown]
# Do you think the results are better ? What difference can you see ? What advantage does the Variational Autoencoder have over the simple autoencoder model, even though the second autoencoder approach has a more complex probabilistic latent model (a full covariance matrix) ?
#
#
# The numbers look much clearer than the other autoencoder models from before. The advantage of a VAE compared to the other models that we did is that we are forcing some distributions (mainly the encoder one) to be close to a known prior. We don't need to to estimate parameters like before.

# %% [markdown]
# ### Statistics of $q_\phi$
#
# Remember, our goal was to create an autoencoder such that the distributions $q_{\phi}(z|x)$ of each input data point in the latent space is a normal distribution, ie such that $\mu=0$ and $\sigma=1$ for all inputs. Let us see if this goal was attained.
#
# For this, take a batch of test images, and calculate the vectors $\mu=0$ and $\sigma=1$ of these images (recall that they should be 0 and 1). Now,use a 2D scatter plot on any two of the latent coordinates to visualise the values of $\mu$ and $\sigma$ (you can try several different combinations of the latent coordinates).
#
# You will need to use ```detach().numpy()``` to plot these values.

# %%
# FILL IN STUDENT
vae_model.eval()

with torch.no_grad():
    data, _ = next(iter(mnist_test_loader))
    mu, log_var = vae_model.encoder(data)

    sigma = torch.exp(0.5 * log_var)

    mu_np = mu.detach().numpy()
    sigma_np = sigma.detach().numpy()

# %%
import matplotlib.pyplot as plt

i, j = 0, 1  # try different pairs

plt.figure(figsize=(5, 5))
plt.scatter(mu_np[:, i], mu_np[:, j], alpha=0.6)
plt.axhline(0, color='red', linestyle='--')
plt.axvline(0, color='red', linestyle='--')
plt.xlabel(f"μ[{i}]")
plt.ylabel(f"μ[{j}]")
plt.title("Latent mean distribution")
plt.show()

# %% [markdown]
# Do we indeed see most values around $\mu=0$, $\sigma=1$ ? Is this in fact possible ? Why ? What compromise are we trying to achieve ?

# %% [markdown]
# __Your answer:__
#
# Points are scattered around the point (0,0). There are no correlation among the points, so we have a big variability.

# %% [markdown]
# Let us now compare the three models (AE diagonal covariance, AE full covariance and VAE) quantitavely.

# %% [markdown]
# # 4 Evaluating and comparing the models
#
# We will evaluate the models, in the following manner:
#
# - we train a simple convolutional neural network classifier on mnist, to a good accuracy
# - we generate images with each model
# - we find the average of the highest probability of the images according to the classifier, for each model. If this value is high, it means that on average the classifier considers that the images look like a number
#
# We will use the following convoluional architecture for the classifier:
#
# - conv2d, filter size  3×3 , 32 filters, stride=(2,2), padding="SAME"
# - ReLU
# - conv2d, filter size  3×3 , 32 filters, stride=(2,2), padding="SAME"
# - ReLU
# - MaxPool2D, stride=(2,2)
# - Flatten
# - Dense layer
#
# Now, define the model. To make things easier, use the ```torch.nn.Sequential``` API (there is no need for a Class in this simple case).

# %%
learning_rate = 0.01
n_epochs = 20
batch_size = 64
nb_classes = int(mnist_trainset.targets.max()+1)

# number of convolutional filters to use
nb_filters = 32
# convolution kernel size
kernel_size = (3, 3)
# size of pooling area for max pooling
pool_size = (2, 2)

# --- Size of the successive layers
n_h_0 = 1 #greyscale input images
n_h_1 = nb_filters
n_h_2 = nb_filters

mnist_classification_model = torch.nn.Sequential(
    torch.nn.Conv2d(n_h_0, n_h_1, kernel_size=3, stride=2, padding=1),
    torch.nn.ReLU(),

    torch.nn.Conv2d(n_h_1, n_h_2, kernel_size=3, stride=2, padding=1),
    torch.nn.ReLU(),

    torch.nn.MaxPool2d(2),

    torch.nn.Flatten(),

    torch.nn.Linear(n_h_2 * 3 * 3, nb_classes)
)

# FILL IN CODE HERE

criterion = torch.nn.CrossEntropyLoss() # FILL IN CODE HERE
optimizer = torch.optim.Adam(mnist_classification_model.parameters(), lr=learning_rate)

# %% [markdown]
# Create a function to calculate accuracy, instead of loss

# %%
def get_accuracy(x_pred,x_label):
  acc = torch.sum(x_pred == x_label)/(x_pred.shape[0])
  return acc

# %% [markdown]
# Now, train the model. You should be able to achieve an accuracy close to 1.00 within 20 epochs

# %%
train_losses=[]
valid_losses=[]

for epoch in range(0,n_epochs):
  train_loss=0.0

  for batch_idx, (imgs, labels) in enumerate(mnist_train_loader):

    # set the gradients back to 0
    optimizer.zero_grad()
    predict=mnist_classification_model(imgs)
    # apply loss function
    loss=criterion(predict,labels)
    acc = get_accuracy(torch.argmax(predict,dim=1),labels)
    # backpropagation
    loss.backward()
    optimizer.step()
    train_loss=loss.item()
  print('Epoch:{} Train Loss:{:.4f} Accuracy:{:.4f}'.format(epoch,train_loss/imgs.shape[0],acc))
# Out:
# Epoch:0 Train Loss:0.0156 Accuracy:0.3516
# Epoch:1 Train Loss:0.0083 Accuracy:0.6250
# Epoch:2 Train Loss:0.0043 Accuracy:0.8047
# Epoch:3 Train Loss:0.0009 Accuracy:0.9922
# Epoch:4 Train Loss:0.0022 Accuracy:0.8906
# Epoch:5 Train Loss:0.0016 Accuracy:0.9375
# Epoch:6 Train Loss:0.0018 Accuracy:0.9141
# Epoch:7 Train Loss:0.0004 Accuracy:0.9844
# Epoch:8 Train Loss:0.0011 Accuracy:0.9609
# Epoch:9 Train Loss:0.0007 Accuracy:0.9844
# Epoch:10 Train Loss:0.0004 Accuracy:0.9844
# Epoch:11 Train Loss:0.0004 Accuracy:0.9844
# Epoch:12 Train Loss:0.0003 Accuracy:0.9922
# Epoch:13 Train Loss:0.0001 Accuracy:1.0000
# Epoch:14 Train Loss:0.0002 Accuracy:0.9922
# Epoch:15 Train Loss:0.0001 Accuracy:1.0000
# Epoch:16 Train Loss:0.0001 Accuracy:1.0000
# Epoch:17 Train Loss:0.0001 Accuracy:1.0000
# Epoch:18 Train Loss:0.0000 Accuracy:1.0000
# Epoch:19 Train Loss:0.0000 Accuracy:1.0000

# %% [markdown]
# ### Evaluate the average maximum prediction of the images generated by each generative model (higher is better)
#
# Now, we will evaluate the models. For each ones, produce a certain number of images, and put those images through the classification network. Then find the maximum class probability of each image, and average it over all the images. We will use this as a metric to evaluate each model.
#
# __CAREFUL__: the output of the network does __not__ include the Softmax layer, so you will have to carry it out, with:
# - ```torch.nn.Softmax()(...)```
#
# Define this metric now:

# %%
def generative_model_score(imgs_in,classification_model):
  logits = classification_model(imgs_in)
  probs = torch.nn.Softmax(dim=1)(logits)
  max_probs, _ = torch.max(probs, dim=1)
  gen_score = torch.mean(max_probs) # FILL IN CODE HERE
  return(gen_score)

# %% [markdown]
# Now, generate some images with each of the three models, and evaluate these models:

# %%
imgs_diagonal_gaussian = generate_images_diagonal_gaussian(ae_model,z_average,z_sigma,n_images = 50)
imgs_non_diagonal_gaussian = generate_images_non_diagonal_gaussian(ae_model,z_average,z_covariance,n_images = 50)
imgs_vae = generate_images_vae(vae_model,n_images=50)

# average of maximum of first model
diagonal_gaussian_score = float(generative_model_score(imgs_diagonal_gaussian,mnist_classification_model))
non_diagonal_gaussian_score = float(generative_model_score(imgs_non_diagonal_gaussian,mnist_classification_model))
vae_gaussian_score = float(generative_model_score(imgs_vae,mnist_classification_model))

print("Diagonal gaussian generative model score : ",diagonal_gaussian_score)
print("Non diagonal gaussian generative model score : ",non_diagonal_gaussian_score)
print("Variational autoencoder model score: ",vae_gaussian_score)
# Out:
# Diagonal gaussian generative model score :  0.8480173349380493
# Non diagonal gaussian generative model score :  0.8778981566429138
# Variational autoencoder model score:  0.8532567024230957
# /tmp/ipython-input-2102764944.py:6: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:836.)
#   diagonal_gaussian_score = float(generative_model_score(imgs_diagonal_gaussian,mnist_classification_model))

# %% [markdown]
# Please answer the following questions:
#
# - Which model is better quantitatively ?
# - Do the quantitative result support the qualitative results ?
# - Can you see any drawbacks of this method of evaluation ?
# - Can you propose any more sophisticated models than the multivariate Gaussian approach (apart from the variational autoencoder) ?

# %% [markdown]
# __Your answer__
# Non diagonal Gaussian autoencoder achieved the highest generative model score, so having correlations in the latent space helped a lot. However, from a visual perspective, VAE was better even though the score was a bit low. Other models that could be used are RBM, GANs, Diffusion Models, Normalizing Flows ...

# %% [markdown]
# ## 5 Conclusion
#
# Summarise the advantages and disadvantages of the variational autoencoder, with respect with what you have seen in this lab. In particular, discuss the following points :
# - The advantages/drawbacks of the Gaussian model in the latent space ($q_\theta(z|x)$)
# - The advantages/drawbacks of the Bernoulli or Gaussian models for the image space ($p_\theta(x|z)$)
# - To what extent is the initial goal achieved, ie creating an autoencoder whose latent codes follow a (multi-dimensional) normal distribution;

# %% [markdown]
# __Answer__
